# %% [markdown]
# # Intro to Python
#
# Ling 571
# Oct 11, 2018

# %% [markdown]
# ## Expressions
#
# Python calculates the value of basic mathematical expressions

# %%
1 + 1
# Out:
# 2

# %%
5 * 6 - 1
# Out:
# 29

# %%
1 / 2
# Out:
# 0.5

# %%
3.5  * -3
# Out:
# -10.5

# %% [markdown]
# How many weeks in one million seconds?

# %%
1000000 / 7 / 24 / 60 / 60
# Out:
# 1.6534391534391537

# %%
# %precision 2
# Out:
# '%.2f'

# %%
1000000 / 7 / 24 / 60 / 60
# Out:
# 1.65

# %%
6 / 2
# Out:
# 3.00

# %% [markdown]
# Division by zero raises an *exception* (i.e., an error)

# %%
6 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-9-35ab704efce5> in <module>()
# ----> 1 6 / 0
#
# ZeroDivisionError: division by zero

# %%
'eep'
# Out:
# 'eep'

# %%
"eep"
# Out:
# 'eep'

# %%
'b' + 'eep'
# Out:
# 'beep'

# %%
'b' + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-2265675451ef> in <module>()
# ----> 1 'b' + 5
#
# TypeError: must be str, not int

# %%
'b' + '5'
# Out:
# 'b5'

# %%
'4' + '5'
# Out:
# '45'

# %%
'b' + 0.5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-803be5f44c28> in <module>()
# ----> 1 'b' + 0.5
#
# TypeError: must be str, not float

# %%
'b' * 5
# Out:
# 'bbbbb'

# %%
'b' * '5'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-67a8341dc6be> in <module>()
# ----> 1 'b' * '5'
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
1 + 1
2 + 2
# Out:
# 4

# %% [markdown]
# ## Variables

# %%
x = 5 * 2

# %%
y = x * 10

# %%
x
# Out:
# 10

# %%
y
# Out:
# 100

# %%
x = 50
x
# Out:
# 50

# %%
z = y
y = 25

# %%
y
# Out:
# 25

# %%
z
# Out:
# 100

# %%
msg = 'eep'

# %%
'b' + msg
# Out:
# 'beep'

# %%
b + msg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-3a3a4347838d> in <module>()
# ----> 1 b + msg
#
# NameError: name 'b' is not defined

# %%
msg
# Out:
# 'eep'

# %% [markdown]
# ## Functions

# %%
abs(5)
# Out:
# 5

# %%
abs(-5)
# Out:
# 5

# %%
2 * abs(-5)
# Out:
# 10

# %%
x = -5
abs(x)
# Out:
# 5

# %%
x
# Out:
# -5

# %%
int('32')
# Out:
# 32

# %%
int('32') + 5
# Out:
# 37

# %%
len('beep')
# Out:
# 4

# %%
len(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-91fed648bb37> in <module>()
# ----> 1 len(5)
#
# TypeError: object of type 'int' has no len()

# %%
print('The answer is =')
1
# Out:
# The answer is =
# 1

# %%
len('The answer is =')
# Out:
# 15

# %% [markdown]
# ## Lists and sets

# %%
[ 'This', 'is', 'a', 'list' ]
# Out:
# ['This', 'is', 'a', 'list']

# %%
L = _

# %%
L
# Out:
# ['This', 'is', 'a', 'list']

# %%
len(L)
# Out:
# 4

# %%
M = L + ['so','is','this','one']
M
# Out:
# ['This', 'is', 'a', 'list', 'so', 'is', 'this', 'one']

# %%
N = [[1,2,3],[4,5,6]]
len(N)
# Out:
# 2

# %% [markdown]
# List indexing

# %%
M[0]
# Out:
# 'This'

# %%
M[1]
# Out:
# 'is'

# %%
M[-1]
# Out:
# 'one'

# %% [markdown]
# List slices

# %%
M[0:3]
# Out:
# ['This', 'is', 'a']

# %%
X = [0, 1, 2, 3, 4, 5, 6]
X[0:4]
# Out:
# [0, 1, 2, 3]

# %%
X[2:5]
# Out:
# [2, 3, 4]

# %%
X[2:2]
# Out:
# []

# %%
X[3:2]
# Out:
# []

# %%
X[2:3]
# Out:
# [2]

# %%
X[2]
# Out:
# 2

# %% [markdown]
# Sets

# %%
M
# Out:
# ['This', 'is', 'a', 'list', 'so', 'is', 'this', 'one']

# %%
set(M)
# Out:
# {'This', 'a', 'is', 'list', 'one', 'so', 'this'}

# %%
S = set(M)

# %%
S[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-9ff278f294d3> in <module>()
# ----> 1 S[0]
#
# TypeError: 'set' object does not support indexing

# %%
list(S)[0]
# Out:
# 'is'

# %%
len(S)
# Out:
# 7

# %%
len(M)
# Out:
# 8
